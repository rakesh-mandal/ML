# %% [markdown]
# <a href="https://colab.research.google.com/github/rakesh-mandal/ML/blob/main/day19-understanding%20your%20data%20descriptive%20%20stats/day19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %% [markdown]
# # 1. How big is the data?

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# # 2. How does the data look like?

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                           Name     Sex  \
# 494          495         0       3     Stanley, Mr. Edward Roland    male
# 573          574         1       3              Kelly, Miss. Mary  female
# 589          590         0       3            Murdlin, Mr. Joseph    male
# 741          742         0       1  Cavendish, Mr. Tyrell William    male
# 324          325         0       3       Sage, Mr. George John Jr    male
#
#       Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 494  21.0      0      0   A/4 45380   8.05   NaN        S
# 573   NaN      0      0       14312   7.75   NaN        Q
# 589   NaN      0      0  A./5. 3235   8.05   NaN        S
# 741  36.0      1      0       19877  78.85   C46        S
# 324   NaN      8      2    CA. 2343  69.55   NaN        S

# %% [markdown]
# # 3. What is the data type of cols?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Change datatype af Age
df['Age'].isnull().sum()
# Out:
# np.int64(177)

# %%
# Convert to nullable integer (Int64). This preserves missing values.
df['Age'].astype('Int64')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/arrays/integer.py in _safe_cast(cls, values, dtype, copy)
#      52         try:
# ---> 53             return values.astype(dtype, casting="safe", copy=copy)
#      54         except TypeError as err:
#
# TypeError: Cannot cast array data from dtype('float64') to dtype('int64') according to the rule 'safe'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1793/3343019953.py in <cell line: 0>()
#       1 # Convert to nullable integer (Int64). This preserves missing values.
# ----> 2 df['Age'].astype('Int64')
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6641         else:
# ...

# %%
df['Age'].notna().sum()
# Out:
# np.int64(714)

# %%
df['Age'].isnull().sum()
# Out:
# np.int64(177)

# %%
(df['Age'].notna() & (df['Age'] % 1 != 0)).sum()
# Out:
# np.int64(25)

# %%
df[df['Age'].notna() & (df['Age'] % 1 != 0)]['Age']
# Out:
# 57     28.50
# 78      0.83
# 111    14.50
# 116    70.50
# 122    32.50
# 123    32.50
# 148    36.50
# 152    55.50
# 153    40.50
# 203    45.50
# 227    20.50
# 296    23.50
# 305     0.92
# 331    45.50
# 469     0.75
# 525    40.50
# 644     0.75
# 676    24.50
# 735    28.50
# 755     0.67
# 767    30.50
# 803     0.42
# 814    30.50
# 831     0.83
# 843    34.50
# Name: Age, dtype: float64

# %%
df.loc[df['Age'].notna() & (df['Age'] % 1 != 0), 'Age']
# Out:
# 57     28.50
# 78      0.83
# 111    14.50
# 116    70.50
# 122    32.50
# 123    32.50
# 148    36.50
# 152    55.50
# 153    40.50
# 203    45.50
# 227    20.50
# 296    23.50
# 305     0.92
# 331    45.50
# 469     0.75
# 525    40.50
# 644     0.75
# 676    24.50
# 735    28.50
# 755     0.67
# 767    30.50
# 803     0.42
# 814    30.50
# 831     0.83
# 843    34.50
# Name: Age, dtype: float64

# %%
df.loc[df['Age'] > 60]
#df.loc[df['Age'] > 60, 'Name']
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 33            34         0       2                      Wheadon, Mr. Edward H
# 54            55         0       1             Ostby, Mr. Engelhart Cornelius
# 96            97         0       1                  Goldschmidt, Mr. George B
# 116          117         0       3                       Connors, Mr. Patrick
# 170          171         0       1                  Van der hoef, Mr. Wyckoff
# 252          253         0       1                  Stead, Mr. William Thomas
# 275          276         1       1          Andrews, Miss. Kornelia Theodosia
# 280          281         0       3                           Duane, Mr. Frank
# 326          327         0       3                  Nysveen, Mr. Johan Hansen
# 438          439         0       1                          Fortune, Mr. Mark
# 456          457         0       1                  Millet, Mr. Francis Davis
# ...

# %%
24.5%1
# Out:
# 0.5

# %%
df[df['Age']>60]['Name']
# Out:
# 33                         Wheadon, Mr. Edward H
# 54                Ostby, Mr. Engelhart Cornelius
# 96                     Goldschmidt, Mr. George B
# 116                         Connors, Mr. Patrick
# 170                    Van der hoef, Mr. Wyckoff
# 252                    Stead, Mr. William Thomas
# 275            Andrews, Miss. Kornelia Theodosia
# 280                             Duane, Mr. Frank
# 326                    Nysveen, Mr. Johan Hansen
# 438                            Fortune, Mr. Mark
# 456                    Millet, Mr. Francis Davis
# 483                       Turkula, Mrs. (Hedwig)
# 493                      Artagaveytia, Mr. Ramon
# 545                 Nicholson, Mr. Arthur Ernest
# 555                           Wright, Mr. George
# 570                           Harris, Mr. George
# 625                        Sutton, Mr. Frederick
# 630         Barkworth, Mr. Algernon Henry Wilson
# 672                  Mitchell, Mr. Henry Michael
# ...

# %%
import numpy as np

s = pd.Series([22.0, 38.0, np.nan, 35])

s = s.astype('Int32')

print(s)
print(s.dtype)
# Out:
# 0      22
# 1      38
# 2    <NA>
# 3      35
# dtype: Int32
# Int32

# %% [markdown]
# # 4. Are there any missing values?

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # 5. How does the data look mathematically?

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # 6. Are there duplicate values?

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # 7. How is the correlation between cols?

# %%
df.corr()['Survived']
# Out:
# PassengerId   -0.005007
# Survived       1.000000
# Pclass        -0.338481
# Age           -0.077221
# SibSp         -0.035322
# Parch          0.081629
# Fare           0.257307
# Name: Survived, dtype: float64
