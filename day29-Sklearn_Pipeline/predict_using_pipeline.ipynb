# %% [markdown]
# <a href="https://colab.research.google.com/github/rakesh-mandal/ML/blob/main/day29-Sklearn_Pipeline/predict_using_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pickle

# %%
import numpy as np

# %%
# Assume user input
test_input2 = np.array([2, 'male', 31.0, 0, 0, 10.5, 'S'],dtype=object).reshape(1,7)

# %%
type(test_input2)
# Out:
# numpy.ndarray

# %%
import pickle
pipe = pickle.load(open('model.pkl','rb'))

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'model.pkl', 'sample_data']

# %%
pipe.predict(test_input2)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0])

# %%
import pandas as pd

test_input2 = pd.DataFrame({
    'Pclass': [1],
    'Sex': ['male'],
    'Age': [25],
    'SibSp': [0],
    'Parch': [0],
    'Fare': [50],
    'Embarked': ['S']
})

pipe.predict(test_input2)
# Out:
# array([0])
