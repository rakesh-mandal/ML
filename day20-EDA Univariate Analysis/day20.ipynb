# %% [markdown]
# <a href="https://colab.research.google.com/github/rakesh-mandal/ML/blob/main/day20-EDA%20Univariate%20Analysis/day20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('train.csv')

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 195          196         1       1
# 165          166         1       3
# 181          182         0       2
# 545          546         0       1
# 7              8         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 195                             Lurette, Miss. Elise  female  58.0      0
# 165  Goldsmith, Master. Frank John William "Frankie"    male   9.0      0
# 181                                 Pernot, Mr. Rene    male   NaN      0
# 545                     Nicholson, Mr. Arthur Ernest    male  64.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
#
#      Parch         Ticket      Fare Cabin Embarked
# 195      0       PC 17569  146.5208   B80        C
# 165      2         363291   20.5250   NaN        S
# 181      0  SC/PARIS 2131   15.0500   NaN        C
# 545      0            693   26.0000   NaN        S
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df['Age'].isnull().sum()
# Out:
# np.int64(177)

# %%
#To find the number of non-null values in the Age column:
df['Age'].count()
# Out:
# np.int64(714)

# %%
df['Age'].notna().sum()
# Out:
# np.int64(714)

# %%
#To get all numerical columns in a DataFrame:
df.select_dtypes(include='number').columns.tolist()
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %%
#To get only categorical columns:
df.select_dtypes(include='object').columns.tolist()
# Out:
# ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df['Sex'].value_counts(normalize=True)*100
# Out:
# Sex
# male      64.758698
# female    35.241302
# Name: proportion, dtype: float64

# %% [markdown]
# # 1. Categorical Data

# %% [markdown]
# ###a. Countplot

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df['Sex'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Sex'>

# %%
import seaborn as sns

# %%
sns.countplot(x=df['Embarked'])
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %% [markdown]
# ###b. pie chart

# %%
df['Sex'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# #2. Numerical Data

# %% [markdown]
# ###a. histogram

# %%
# To understand distribution
import matplotlib.pyplot as plt
plt.hist(df['Age'],bins=5)
# Out:
# (array([100., 346., 188.,  69.,  11.]),
#  array([ 0.42 , 16.336, 32.252, 48.168, 64.084, 80.   ]),
#  <BarContainer object of 5 artists>)

# %%
df['Age'].plot(kind='density')
#plt.show()
# Out:
# <Axes: ylabel='Density'>

# %%
sns.distplot(df['Age'])
# Out:
# /tmp/ipykernel_685/3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
#KDE=Kernel Density Estimation.
sns.histplot(df['Age'], kde=True)
plt.show()

# %% [markdown]
# #b boxplot

# %%
#outlier detection
plt.boxplot(df['Age'])
plt.show()

# %%
sns.boxplot(x=df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
#skewness
df['Age'].skew()
# Out:
# np.float64(0.38910778230082704)

# %%
"""
Skewness	Meaning
= 0	Symmetric
> 0	Right Skewed
< 0	Left Skewed
"""
# Out:
# '\nSkewness\tMeaning\n= 0\tSymmetric\n> 0\tRight Skewed\n< 0\tLeft Skewed\n'
